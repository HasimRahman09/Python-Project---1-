# %% [markdown]
# # ASSESSMENT 2 TASK 2 - PART B  - Exploratory Data Analysis (EDA)
# ### Student Name:Hasim Rahman
# ### Student ID: 24674715
# ### Date: 23 October 2023

# %% [markdown]
# ## Business Problem
# Introduction: The data selected deals with the salaries for people working in data science.
# The purpose for the analysis is to find out key insights and deeper grasp of the results from
# the selected dataset, find trend/patterns and also find correlation amongst the elements of
# the dataset. The purpose of the visualisation is to identify and explain the trends found in
# the dataset, present them in a digestible and clear way for the readers.
# #### Describe your business problem and data visualization question
# The business problem we are dealing with is to find learning which and how many programming languages will have a direct effect on a data scientists salary and also how the categorical variables effect the salaries for a person looking for a job in this field

# %% [markdown]
# # Reading Data
#
# ### Import the dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/salary_data_cleaned.csv")

# %% [markdown]
# ## Explore the data
# Hint: Pandas: Pandas is one of the most popular libraries for data manipulation and exploration.
#
# * df.head(): View the first few rows of a DataFrame.
# * df.tail(): View the last few rows of a DataFrame.

# %%
df.head(2)
# Out:
#                    Job Title              Salary Estimate  \
# 0             Data Scientist   $53K-$91K (Glassdoor est.)
# 1  Healthcare Data Scientist  $63K-$112K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
#
#                                  Company Name         Location   Headquarters  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM     Goleta, CA
# 1  University of Maryland Medical System\n3.4    Linthicum, MD  Baltimore, MD
#
#                     Size  Founded   Type of ownership  ... avg_salary  \
# 0  501 to 1000 employees     1973   Company - Private  ...       72.0
# 1       10000+ employees     1984  Other Organization  ...       87.5
#
#                                company_txt job_state same_state  age  \
# 0                      Tecolote Research\n        NM          0   47
# ...

# %%
df.tail(2)
# Out:
#                                      Job Title              Salary Estimate  \
# 740                       Data Science Manager  $95K-$160K (Glassdoor est.)
# 741  Research Scientist – Security and Privacy  $61K-$126K (Glassdoor est.)
#
#                                        Job Description  Rating  \
# 740  Data Science ManagerResponsibilities:\n\nOvers...     3.2
# 741  Returning Candidate? Log back in to the Career...     3.6
#
#                           Company Name         Location     Headquarters  \
# 740                  Numeric, LLC\n3.2    Allentown, PA  Chadds Ford, PA
# 741  Riverside Research Institute\n3.6  Beavercreek, OH    Arlington, VA
#
#                       Size  Founded       Type of ownership  ... avg_salary  \
# 740      1 to 50 employees       -1       Company - Private  ...      127.5
# 741  501 to 1000 employees     1967  Nonprofit Organization  ...       93.5
#
#                         company_txt job_state same_state  age  python_yn  \
# ...

# %%
print(df.shape)
print(df.columns)
# Out:
# (742, 28)
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_salary', 'max_salary', 'avg_salary',
#        'company_txt', 'job_state', 'same_state', 'age', 'python_yn', 'R_yn',
#        'spark', 'aws', 'excel'],
#       dtype='object')

# %% [markdown]
# ## Data understanding
# Generate statistics using
# * df.info(): Get information about the DataFrame, including data types and missing values.
# * df.describe(): Generate summary statistics for numerical columns.
# * df.value_counts(): Count unique values in a column.

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 742 entries, 0 to 741
# Data columns (total 28 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Job Title          742 non-null    object
#  1   Salary Estimate    742 non-null    object
#  2   Job Description    742 non-null    object
#  3   Rating             742 non-null    float64
#  4   Company Name       742 non-null    object
#  5   Location           742 non-null    object
#  6   Headquarters       742 non-null    object
#  7   Size               742 non-null    object
#  8   Founded            742 non-null    int64
#  9   Type of ownership  742 non-null    object
#  10  Industry           742 non-null    object
#  11  Sector             742 non-null    object
#  12  Revenue            742 non-null    object
#  13  Competitors        742 non-null    object
#  14  hourly             742 non-null    int64
#  15  employer_provided  742 non-null    int64
# ...

# %%
df.describe()
# Out:
#            Rating      Founded      hourly  employer_provided  min_salary  \
# count  742.000000   742.000000  742.000000         742.000000  742.000000
# mean     3.618868  1837.154987    0.032345           0.022911   74.068733
# std      0.801210   497.183763    0.177034           0.149721   31.869282
# min     -1.000000    -1.000000    0.000000           0.000000   10.000000
# 25%      3.300000  1939.000000    0.000000           0.000000   52.000000
# 50%      3.700000  1988.000000    0.000000           0.000000   69.500000
# 75%      4.000000  2007.000000    0.000000           0.000000   91.000000
# max      5.000000  2019.000000    1.000000           1.000000  202.000000
#
#        max_salary  avg_salary  same_state         age   python_yn        R_yn  \
# count  742.000000  742.000000  742.000000  742.000000  742.000000  742.000000
# mean   127.183288  100.626011    0.557951   46.591644    0.528302    0.002695
# ...

# %%
df.value_counts()
print(df['Job Title'].value_counts())
print(df['Location'].value_counts())
print(df['Type of ownership'].value_counts())
print(df['Sector'].value_counts())
print(df['company_txt'].value_counts())
# Out:
# Data Scientist                     131
# Data Engineer                       53
# Senior Data Scientist               34
# Data Analyst                        15
# Senior Data Engineer                14
#                                   ...
# Data Scientist/ML Engineer           1
# Sr. Data Scientist                   1
# Data Engineer 4 - Contract           1
# Data Analyst - Asset Management      1
# Machine Learning Engineer (NLP)      1
# Name: Job Title, Length: 264, dtype: int64
# New York, NY                         55
# San Francisco, CA                    49
# Cambridge, MA                        47
# Chicago, IL                          32
# Boston, MA                           23
#                                      ..
# Santa Fe Springs, Los Angeles, CA     1
# Kansas City, MO                       1
# Columbia, SC                          1
# Red Bank, NJ                          1
# Olympia, WA                           1
# ...

# %% [markdown]
# # Data preparation

# %%
# Replace "Los Angeles" with "LA" in the 'job_state' column
df['job_state'] = df['job_state'].replace({'Los Angeles': 'LA'})

# %% [markdown]
# ## Checking Null or Missing Values
# Hint: df.isnull(): Check for missing values.

# %%
missing_data = df.isnull().sum()

# %%
df = df.dropna()

# %%
missing_data
# Out:
# Job Title            0
# Salary Estimate      0
# Job Description      0
# Rating               0
# Company Name         0
# Location             0
# Headquarters         0
# Size                 0
# Founded              0
# Type of ownership    0
# Industry             0
# Sector               0
# Revenue              0
# Competitors          0
# hourly               0
# employer_provided    0
# min_salary           0
# max_salary           0
# avg_salary           0
# company_txt          0
# job_state            0
# same_state           0
# age                  0
# python_yn            0
# R_yn                 0
# spark                0
# aws                  0
# excel                0
# dtype: int64

# %% [markdown]
# ## Visualize missing values

# %%
#Example
import pandas as pd
import matplotlib.pyplot as plt

df = pd.DataFrame(df)

# Count the number of missing values
missing_values_count = df.isnull().sum()

# Create a bar chart to visualize missing values
plt.figure(figsize=(8, 6))
missing_values_count.plot(kind='bar', color='blue')
plt.title('Number of Missing Values by Column')
plt.xlabel('Columns')
plt.ylabel('Number of Missing Values')
plt.xticks(rotation=0)  # Rotate x-axis labels for better readability
plt.show()

# %% [markdown]
# ## Checking Duplicate Values
# Hint: function drop_duplicates()

# %%
# Check for duplicate rows
duplicate_rows = df[df.duplicated()]
# Dropping duplicate rows based on all columns
df.drop_duplicates(inplace=True)

# Display the duplicate rows
print("Duplicate Rows:")
print(duplicate_rows)
# Out:
# Duplicate Rows:
#                                              Job Title  \
# 29                                      Data Scientist
# 30                                      Data Scientist
# 58                                      Data Scientist
# 59                                      Data Scientist
# 86                   Staff Data Scientist - Technology
# ..                                                 ...
# 737           Sr Scientist, Immuno-Oncology - Oncology
# 738                               Senior Data Engineer
# 739  Project Scientist - Auton Lab, Robotics Institute
# 740                               Data Science Manager
# 741          Research Scientist – Security and Privacy
#
#                   Salary Estimate  \
# 29     $80K-$90K (Glassdoor est.)
# 30     $56K-$97K (Glassdoor est.)
# 58     $54K-$93K (Glassdoor est.)
# 59    $71K-$119K (Glassdoor est.)
# 86   $106K-$172K (Glassdoor est.)
# ..                            ...
# 737   $58K-$111K (Glassdoor est.)
# ...

# %% [markdown]
# # Checking for Outliers
# detecting outliers

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Select the 'Rating' and 'Founded', 'Employer provided' and 'age' columns for box plots
columns_to_plot = ['Rating', 'Founded','employer_provided','age']

# Create a box plot for each column
fig, axes = plt.subplots(nrows=1, ncols=len(columns_to_plot), figsize=(12, 6))
fig.suptitle('Box Plots for Rating and Founded Columns', fontsize=16)

for i, column in enumerate(columns_to_plot):
    sns.boxplot(x=df[column], ax=axes[i])
    axes[i].set_title(column)

# Adjust layout
plt.tight_layout(rect=[0, 0, 1, 0.9])
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Select the salary columns to create box plots
columns_to_plot = ['min_salary', 'max_salary', 'avg_salary']

# Create a box plot for each column
fig, axes = plt.subplots(nrows=1, ncols=len(columns_to_plot), figsize=(18, 6))
fig.suptitle('Box Plots for Salary Columns', fontsize=20)

for i, column in enumerate(columns_to_plot):
    sns.boxplot(x=df[column], ax=axes[i])
    axes[i].set_title(column)

# Adjust layout
plt.tight_layout(rect=[0, 0, 1, 0.9])
plt.show()

# %% [markdown]
# ##Take appropriate actions to handle the outliers.

# %%
#Example from data above
# Define a function to remove outliers based on the IQR(Interquartile range) method for specific columns (we will not be removing outliers from the salary columns)
def remove_outliers_iqr(column):
    if column.name in ['Rating', 'Founded', 'employer_provided', 'age']:
        Q1 = column.quantile(0.25)
        Q3 = column.quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        return column[(column >= lower_bound) & (column <= upper_bound)]
    else:
        return column  # Return other columns as they are

# Create a new DataFrame to store the cleaned data
df_cleaned = df.copy()

# Apply the remove_outliers_iqr function to specific columns
df_cleaned = df_cleaned.apply(remove_outliers_iqr)

# Display the cleaned DataFrame
print("Original DataFrame:")
print(df[['Rating', 'Founded', 'employer_provided', 'age']])
print("\nDataFrame with Outliers Removed:")
print(df_cleaned[['Rating', 'Founded', 'employer_provided', 'age']])


# Apply the remove_outliers_iqr function to each column
df_cleaned = df.apply(remove_outliers_iqr)

# Display the cleaned DataFrame
print("Original DataFrame:")
print(df)
print("\nDataFrame with Outliers Removed:")
print(df_cleaned)
# Out:
# Original DataFrame:
#      Rating  Founded  employer_provided  age
# 0       3.8     1973                  0   47
# 1       3.4     1984                  0   36
# 2       4.8     2010                  0   10
# 3       3.8     1965                  0   55
# 4       2.9     1998                  0   22
# ..      ...      ...                ...  ...
# 695     4.3     1999                  0   21
# 700     3.4       -1                  0   -1
# 716     4.0     2006                  0   14
# 732     4.1     2007                  0   13
# 735     3.9     2011                  0    9
#
# [467 rows x 4 columns]
#
# DataFrame with Outliers Removed:
#      Rating  Founded  employer_provided   age
# 0       3.8   1973.0                0.0  47.0
# 1       3.4   1984.0                0.0  36.0
# 2       4.8   2010.0                0.0  10.0
# 3       3.8   1965.0                0.0  55.0
# 4       2.9   1998.0                0.0  22.0
# ..      ...      ...                ...   ...
# ...

# %%
# Showing the removed outliers after removing the box plots
columns_to_plot = ['Rating', 'Founded','employer_provided','age']

# Create a box plot for each column
fig, axes = plt.subplots(nrows=1, ncols=len(columns_to_plot), figsize=(12, 6))
fig.suptitle('Box Plots for the columns with outliers removed', fontsize=20)

for i, column in enumerate(columns_to_plot):
    sns.boxplot(x=df_cleaned[column], ax=axes[i])
    axes[i].set_title(column)

# Adjust layout
plt.tight_layout(rect=[0, 0, 1, 0.9])
plt.show()

# %% [markdown]
# # Data visualization to answer the proposed question

# %% [markdown]
# Questions asked from the dataset.

# %% [markdown]
# #Which Programming language leads to a higher salary?

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Filter the data to include only the rows with 'python_yn', 'R_yn', 'spark', 'aws', or 'excel'
filtered_data = df[(df['python_yn'] == 1) | (df['R_yn'] == 1) | (df['spark'] == 1) | (df['aws'] == 1) | (df['excel'] == 1)]

# Set the figure size
plt.figure(figsize=(12, 6))

# Create separate box plots for each programming language
plt.subplot(1, 5, 1)
sns.boxplot(x='python_yn', y='avg_salary', data=filtered_data, color='skyblue')
plt.title('Python')

plt.subplot(1, 5, 2)
sns.boxplot(x='R_yn', y='avg_salary', data=filtered_data, color='skyblue')
plt.title('R')

plt.subplot(1, 5, 3)
sns.boxplot(x='spark', y='avg_salary', data=filtered_data, color='skyblue')
plt.title('Spark')

plt.subplot(1, 5, 4)
sns.boxplot(x='aws', y='avg_salary', data=filtered_data, color='skyblue')
plt.title('AWS')

plt.subplot(1, 5, 5)
sns.boxplot(x='excel', y='avg_salary', data=filtered_data, color='skyblue')
plt.title('Excel')

# Adjust spacing between subplots
plt.tight_layout()

# Show the plots
plt.show()

# %% [markdown]
# From this box plot we can see a clear distinction on salaries offered basing on the skills acquired by the employee.
# The highest difference seems to be if a candidate knows how to use python.
# Jobs not asking for excel seem to have a higher average salary, which could be due to them expecting the person to know excel and they require more specific skills.

# %% [markdown]
# # What is the age distribution of the dataset?

# %%
import matplotlib.pyplot as plt

# Define age groups
age_bins = [20, 30, 40, 50, 60, 70, 80]
age_labels = ['20s', '30s', '40s', '50s', '60s', '70s']

# Create age groups by applying pd.cut to the 'age' column
df['age_group'] = pd.cut(df['age'], bins=age_bins, labels=age_labels, right=False)

# Count the number of data points in each age group
age_group_counts = df['age_group'].value_counts()

# Set the figure size
plt.figure(figsize=(8, 8))

# Create a pie chart
plt.pie(age_group_counts, labels=age_group_counts.index, autopct='%1.1f%%', startangle=140, colors=['skyblue', 'lightcoral', 'lightgreen', 'lightsalmon', 'lightcyan', 'lightpink'])

# Set the title
plt.title('Age Distribution')

# Show the pie chart
plt.show()

# %% [markdown]
# As we can gather from the pie chart most of the employees are quite young, almost 60% are in between 20s and 30s.

# %% [markdown]
# # How are age and salaries affected by the usage of the programming languages?

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Filter the data to include only the rows with 'python_yn', 'R_yn', 'spark', 'aws', or 'excel'
filtered_data = df[(df['python_yn'] == 1) | (df['R_yn'] == 1) | (df['spark'] == 1) | (df['aws'] == 1) | (df['excel'] == 1)]

# Set the figure size
plt.figure(figsize=(15, 6))

# Create separate scatter plots for each programming language
plt.subplot(1, 5, 1)
sns.scatterplot(x='age', y='avg_salary', data=filtered_data[filtered_data['python_yn'] == 1], color='skyblue')
plt.title('Python')

plt.subplot(1, 5, 2)
sns.scatterplot(x='age', y='avg_salary', data=filtered_data[filtered_data['R_yn'] == 1], color='skyblue')
plt.title('R')

plt.subplot(1, 5, 3)
sns.scatterplot(x='age', y='avg_salary', data=filtered_data[filtered_data['spark'] == 1], color='skyblue')
plt.title('Spark')

plt.subplot(1, 5, 4)
sns.scatterplot(x='age', y='avg_salary', data=filtered_data[filtered_data['aws'] == 1], color='skyblue')
plt.title('AWS')

plt.subplot(1, 5, 5)
sns.scatterplot(x='age', y='avg_salary', data=filtered_data[filtered_data['excel'] == 1], color='skyblue')
plt.title('Excel')

# Adjust spacing between subplots
plt.tight_layout()

# Show the plots
plt.show()

# %% [markdown]
# We can interpret the difference in the salary to be expected and from these programming languages. We can see Excel and Python are very popular but Excel is more popular with jobs that pay less.

# %% [markdown]
# # Studying the highest 100 and the lowest 100 jobs

# %%
df['Job Title'].value_counts()
# Out:
# Data Scientist                                          100
# Data Engineer                                            37
# Senior Data Scientist                                    21
# Data Analyst                                             13
# Senior Data Engineer                                      8
#                                                        ...
# Senior Research Statistician- Data Scientist              1
# Business Data Analyst, SQL                                1
# Medical Technologist / Clinical Laboratory Scientist      1
# Associate Data Scientist/Computer Scientist               1
# Machine Learning Engineer (NLP)                           1
# Name: Job Title, Length: 264, dtype: int64

# %%
high_salary_100 = df['avg_salary'].sort_values(ascending=False).head(100)
high_salary_100
# Out:
# 354    254.0
# 103    237.5
# 429    232.5
# 176    225.0
# 613    221.5
#        ...
# 68     128.5
# 344    128.5
# 75     128.0
# 277    128.0
# 437    128.0
# Name: avg_salary, Length: 100, dtype: float64

# %%
low_salary_100 = df['avg_salary'].sort_values().head(100)
low_salary_100
# Out:
# 409    13.5
# 240    15.5
# 210    20.0
# 165    20.5
# 197    21.5
#        ...
# 189    70.5
# 365    70.5
# 324    71.0
# 411    71.5
# 170    71.5
# Name: avg_salary, Length: 100, dtype: float64

# %%
high_salary_100_data = df.loc[high_salary_100.index]
high_salary_100_data.head(2)
# Out:
#                                      Job Title               Salary Estimate  \
# 354  Director II, Data Science - GRM Actuarial  $202K-$306K (Glassdoor est.)
# 103                      Senior Data Scientist    $200K-$275K(Employer est.)
#
#                                        Job Description  Rating  \
# 354  Advance your career at Liberty Mutual Insuranc...     3.3
# 103  Who we want:\nAre you committed to using your ...     4.2
#
#                       Company Name        Location    Headquarters  \
# 354  Liberty Mutual Insurance\n3.3     Chicago, IL      Boston, MA
# 103                    Gallup\n4.2  Washington, DC  Washington, DC
#
#                        Size  Founded  Type of ownership  ...  \
# 354        10000+ employees     1912  Company - Private  ...
# 103  1001 to 5000 employees     1935  Company - Private  ...
#
#                     company_txt job_state same_state  age  python_yn  R_yn  \
# ...

# %%
high_salary_100_data['salary_grade'] = 'high'
high_salary_100_data.head(2)
# Out:
#                                      Job Title               Salary Estimate  \
# 354  Director II, Data Science - GRM Actuarial  $202K-$306K (Glassdoor est.)
# 103                      Senior Data Scientist    $200K-$275K(Employer est.)
#
#                                        Job Description  Rating  \
# 354  Advance your career at Liberty Mutual Insuranc...     3.3
# 103  Who we want:\nAre you committed to using your ...     4.2
#
#                       Company Name        Location    Headquarters  \
# 354  Liberty Mutual Insurance\n3.3     Chicago, IL      Boston, MA
# 103                    Gallup\n4.2  Washington, DC  Washington, DC
#
#                        Size  Founded  Type of ownership  ... job_state  \
# 354        10000+ employees     1912  Company - Private  ...        IL
# 103  1001 to 5000 employees     1935  Company - Private  ...        DC
#
#     same_state  age python_yn  R_yn  spark  aws  excel  age_group salary_grade
# ...

# %%
# select and labeling for low_salary data

low_salary_100_data = df.loc[low_salary_100.index]
low_salary_100_data['salary_grade'] = 'low'
low_salary_100_data.head(2)
# Out:
#                                              Job Title  \
# 409  Senior Operations Data Analyst, Call Center Op...
# 240                                     Data Scientist
#
#                       Salary Estimate  \
# 409  $10-$17 Per Hour(Glassdoor est.)
# 240          $15K-$16K(Employer est.)
#
#                                        Job Description  Rating   Company Name  \
# 409  Summary\n\n\nIndependent contributor role that...     2.7  FLEETCOR\n2.7
# 240  Learn and work on meaningful initiatives with ...     3.9       NPD\n3.9
#
#                 Location           Headquarters                     Size  \
# 409        Nashville, TN  Peachtree Corners, GA  5001 to 10000 employees
# 240  Port Washington, NY    Port Washington, NY   1001 to 5000 employees
#
#      Founded  Type of ownership  ... job_state same_state age python_yn  R_yn  \
# 409     2000   Company - Public  ...        TN          0  20         0     0
# ...

# %%
high_low_salary_200 = pd.concat([high_salary_100_data, low_salary_100_data])
high_low_salary_200.tail(2)
# Out:
#                                              Job Title  \
# 411  RESEARCH COMPUTER SCIENTIST - RESEARCH ENGINEE...
# 170                                      Data Engineer
#
#                 Salary Estimate  \
# 411  $52K-$91K (Glassdoor est.)
# 170  $48K-$95K (Glassdoor est.)
#
#                                        Job Description  Rating  \
# 411  Serve as a software developer and researcher o...     3.9
# 170  IZEA was built to connect the world’s top bran...     4.2
#
#                           Company Name         Location     Headquarters  \
# 411  Southwest Research Institute\n3.9  San Antonio, TX  San Antonio, TX
# 170                          IZEA\n4.2  Winter Park, FL  Winter Park, FL
#
#                        Size  Founded       Type of ownership  ... job_state  \
# 411  1001 to 5000 employees     1947  Nonprofit Organization  ...        TX
# 170     51 to 200 employees     2006        Company - Public  ...        FL
#
# ...

# %% [markdown]
# What is the rating difference between the highest and the lowest salary jobs?

# %%
import matplotlib.pyplot as plt

# Assuming you have the 'high_low_salary_200' DataFrame and the required data

# Grouping the data by 'salary_grade' and 'Rating' to get the data for the box plot
grouped_data = high_low_salary_200.groupby('salary_grade')['Rating'].apply(list)

# Convert the grouped data to a list to pass to Matplotlib
data = [values for key, values in grouped_data.items()]

# Set up the box plot
plt.figure(figsize=(8, 6))
plt.boxplot(data, labels=grouped_data.index, patch_artist=True)
plt.title('Box Plot of Ratings by Salary Grade')
plt.xlabel('Salary Grade')
plt.ylabel('Rating')
plt.grid(axis='y')  # Adding a grid for better readability

# Show the plot
plt.show()

# %% [markdown]
# High relationship between rating and the salary grade

# %% [markdown]
# What is the founding year difference between the highest and the lowest salary jobs?

# %%
# Grouping the data by 'salary_grade' and 'Founded' to prepare for the box plot
grouped_data = high_low_salary_200.groupby('salary_grade')['Founded'].apply(list)

# Convert the grouped data to a list to pass to Matplotlib
data = [values for key, values in grouped_data.items()]

# Set up the box plot using Matplotlib
plt.figure(figsize=(8, 6))
plt.boxplot(data, labels=grouped_data.index, patch_artist=True)
plt.title('Box Plot of Founded by Salary Grade')
plt.xlabel('Salary Grade')
plt.ylabel('Founded')
plt.grid(axis='y')  # Adding a grid for better readability
plt.ylim(1700, 2100)
# Show the plot
plt.show()

# %% [markdown]
# Low effect of founded on the Salary grade

# %% [markdown]
# What is the ages difference between the highest and the lowest salary jobs?

# %%
import matplotlib.pyplot as plt

# Assuming you have the 'high_low_salary_200' DataFrame and the required data

# Grouping the data by 'salary_grade' and 'Founded' to prepare for the box plot
grouped_data = high_low_salary_200.groupby('salary_grade')['age'].apply(list)

# Convert the grouped data to a list to pass to Matplotlib
data = [values for key, values in grouped_data.items()]

# Set up the box plot using Matplotlib
plt.figure(figsize=(8, 6))
plt.boxplot(data, labels=grouped_data.index, patch_artist=True)
plt.title('Box Plot of Ages by Salary Grade')
plt.xlabel('Salary Grade')
plt.ylabel('Age')
plt.grid(axis='y')  # Adding a grid for better readability

# Show the plot
plt.show()

# %% [markdown]
# Low effect of age on the Salary grade

# %% [markdown]
# What job titles have the highest salaries?

# %%
# Count the occurrences of each job title
job_title_counts = high_salary_100_data['Job Title'].value_counts()

# Get the labels (job titles) and their counts
labels = job_title_counts.index
sizes = job_title_counts.values

# Set up the pie chart using Matplotlib
plt.figure(figsize=(10, 8))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
plt.title('High Salary Job Titles')

# Equal aspect ratio ensures that pie is drawn as a circle
plt.axis('equal')

# Show the plot
plt.show()

# %% [markdown]
# Amost all the high paying jobs are typr of Data Scientist jobs

# %% [markdown]
# What job titles have the lowest salaries?

# %%
# Count the occurrences of each job title
job_title_counts = low_salary_100_data['Job Title'].value_counts()

# Get the labels (job titles) and their counts
labels = job_title_counts.index
sizes = job_title_counts.values

# Set up the pie chart using Matplotlib
plt.figure(figsize=(10, 8))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
plt.title('Low Salary Job Titles')

# Equal aspect ratio ensures that pie is drawn as a circle
plt.axis('equal')

# Show the plot
plt.show()

# %% [markdown]
# Very varied division for low paying salaries

# %% [markdown]
# Comparing the highest and lowest for every programming language

# %%
high_low_salary_200.groupby('salary_grade')['python_yn'].sum()
# Out:
# salary_grade
# high    69
# low     31
# Name: python_yn, dtype: int64

# %%
high_low_salary_200.groupby('salary_grade')['R_yn'].sum()
# Out:
# salary_grade
# high    0
# low     1
# Name: R_yn, dtype: int64

# %%
high_low_salary_200.groupby('salary_grade')['spark'].sum()
# Out:
# salary_grade
# high    32
# low     12
# Name: spark, dtype: int64

# %%
high_low_salary_200.groupby('salary_grade')['aws'].sum()
# Out:
# salary_grade
# high    33
# low     13
# Name: aws, dtype: int64

# %%
high_low_salary_200.groupby('salary_grade')['excel'].sum()
# Out:
# salary_grade
# high    52
# low     65
# Name: excel, dtype: int64

# %% [markdown]
# # Studying the states and cities which offer the highest playing salaries

# %%
high_low_salary_200_location = high_low_salary_200[['Location', 'min_salary', 'max_salary', 'avg_salary', 'salary_grade']]
high_low_salary_200_location.head()
# Out:
#               Location  min_salary  max_salary  avg_salary salary_grade
# 354        Chicago, IL         202         306       254.0         high
# 103     Washington, DC         200         275       237.5         high
# 429  San Francisco, CA         176         289       232.5         high
# 176  San Francisco, CA         200         250       225.0         high
# 613  San Francisco, CA         171         272       221.5         high

# %%
v_split = high_low_salary_200_location.Location.str.split(', ')
v_split.head()
# Out:
# 354          [Chicago, IL]
# 103       [Washington, DC]
# 429    [San Francisco, CA]
# 176    [San Francisco, CA]
# 613    [San Francisco, CA]
# Name: Location, dtype: object

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Dividing the state and the cities

# %%
high_low_salary_200_location['city'] = v_split.str.get(0)
high_low_salary_200_location['state'] = v_split.str.get(1)
high_low_salary_200_location = high_low_salary_200_location.drop(['Location'], axis=1)
high_low_salary_200_location
# Out:
#      min_salary  max_salary  avg_salary salary_grade           city state
# 354         202         306       254.0         high        Chicago    IL
# 103         200         275       237.5         high     Washington    DC
# 429         176         289       232.5         high  San Francisco    CA
# 176         200         250       225.0         high  San Francisco    CA
# 613         171         272       221.5         high  San Francisco    CA
# ..          ...         ...         ...          ...            ...   ...
# 189          48          93        70.5          low      Lafayette    LA
# 365          43          98        70.5          low      San Diego    CA
# 324          50          92        71.0          low     Alexandria    VA
# 411          52          91        71.5          low    San Antonio    TX
# 170          48          95        71.5          low    Winter Park    FL
#
# [200 rows x 6 columns]

# %%
high_salary_location = high_low_salary_200_location[high_low_salary_200_location['salary_grade']=='high']
high_salary_location
# Out:
#      min_salary  max_salary  avg_salary salary_grade           city state
# 354         202         306       254.0         high        Chicago    IL
# 103         200         275       237.5         high     Washington    DC
# 429         176         289       232.5         high  San Francisco    CA
# 176         200         250       225.0         high  San Francisco    CA
# 613         171         272       221.5         high  San Francisco    CA
# ..          ...         ...         ...          ...            ...   ...
# 68           96         161       128.5         high   Philadelphia    PA
# 344          97         160       128.5         high        Chicago    IL
# 75           99         157       128.0         high      Vancouver    WA
# 277          95         161       128.0         high       New York    NY
# 437          94         162       128.0         high       New York    NY
#
# [100 rows x 6 columns]

# %%
low_salary_location = high_low_salary_200_location[high_low_salary_200_location['salary_grade']=='low']
low_salary_location
# Out:
#      min_salary  max_salary  avg_salary salary_grade             city state
# 409          10          17        13.5          low        Nashville    TN
# 240          15          16        15.5          low  Port Washington    NY
# 210          15          25        20.0          low      New Orleans    LA
# 165          17          24        20.5          low     West Reading    PA
# 197          18          25        21.5          low         Burleson    TX
# ..          ...         ...         ...          ...              ...   ...
# 189          48          93        70.5          low        Lafayette    LA
# 365          43          98        70.5          low        San Diego    CA
# 324          50          92        71.0          low       Alexandria    VA
# 411          52          91        71.5          low      San Antonio    TX
# 170          48          95        71.5          low      Winter Park    FL
#
# [100 rows x 6 columns]

# %% [markdown]
# High salaries per state

# %%
import matplotlib.pyplot as plt

# Assuming you have the 'high_salary_location' DataFrame and the required data

# Count the occurrences of each state
state_counts = high_salary_location['state'].value_counts()

# Get the labels (state names) and their counts
labels = state_counts.index
sizes = state_counts.values

# Set up the pie chart using Matplotlib
plt.figure(figsize=(6, 6))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
plt.title('High Salary States')

# Equal aspect ratio ensures that pie is drawn as a circle
plt.axis('equal')

# Show the plot
plt.show()

# %% [markdown]
# CA is the most popular for high paying cities.

# %% [markdown]
# High salary per city

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have the 'high_salary_location' DataFrame and the required data

# Count the occurrences of each city
city_counts = high_salary_location['city'].value_counts()

# Display the top cities or select a certain number to display
top_cities = city_counts[:10]  # Considering top 10 cities for illustration

# Set up the pie chart using Matplotlib
plt.figure(figsize=(8, 8))
plt.pie(top_cities, labels=top_cities.index, autopct='%1.1f%%', startangle=140)
plt.title('High Salary Cities')

# Equal aspect ratio ensures that pie is drawn as a circle
plt.axis('equal')

# Show the plot
plt.show()

# %% [markdown]
# San Francisco is the most popular City for high paying jobs

# %% [markdown]
# Lowest salary per state

# %%
import matplotlib.pyplot as plt

# Assuming you have the 'low_salary_location' DataFrame and the required data

# Count the occurrences of each state
state_counts = low_salary_location['state'].value_counts()

# Get the labels (state names) and their counts
labels = state_counts.index
sizes = state_counts.values

# Set up the pie chart using Matplotlib
plt.figure(figsize=(6, 6))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
plt.title('Low Salary States')

# Equal aspect ratio ensures that pie is drawn as a circle
plt.axis('equal')

# Show the plot
plt.show()

# %% [markdown]
# The low salary states are quite varied with MA and CA being the most popular

# %% [markdown]
# Lowest salary per cities

# %%
import matplotlib.pyplot as plt

# Assuming you have the 'low_salary_location' DataFrame and the required data

# Count the occurrences of each city
city_counts = low_salary_location['city'].value_counts()

# Display the top cities or select a certain number to display
top_cities = city_counts[:10]  # Considering top 10 cities for illustration

# Set up the pie chart using Matplotlib
plt.figure(figsize=(8, 8))
plt.pie(top_cities, labels=top_cities.index, autopct='%1.1f%%', startangle=140)
plt.title('Low Salary Cities')

# Equal aspect ratio ensures that the pie is drawn as a circle
plt.axis('equal')

# Show the plot
plt.show()

# %% [markdown]
# NewYork is the most popular low salary city

# %% [markdown]
# What is the number of job listing per programming language?

# %%
import matplotlib.pyplot as plt

# Count the number of job listings for each programming language
language_counts = df[['python_yn', 'R_yn', 'spark', 'aws', 'excel']].sum()

# Set the figure size
plt.figure(figsize=(10, 6))

# Create a bar chart
plt.bar(language_counts.index, language_counts.values, color='skyblue')
plt.title('Count of Job Listings by Programming Language')
plt.xlabel('Programming Language')
plt.ylabel('NUmber of jobs requiring the programming language')

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# 1.   R is the least popular languagage
# 2.   Python and Excel are the most popular
# 3.   Spark and AWS are equally popular

# %% [markdown]
# What is the average salary per state?

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set the figure size
plt.figure(figsize=(12, 6))

# Create a bar plot with Seaborn
sns.barplot(data=df, x='job_state', y='avg_salary', ci=None,)

# Set labels and title
plt.title('Average Salary by State')
plt.xlabel('State')
plt.ylabel('Average Salary')
plt.xticks(rotation=45, ha="right")  # Rotate x-axis labels for readability

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# Texas has the highest average salary

# %% [markdown]
# ## Scatter Plot:
#
# Create a scatter plot to visualize the relationships between two numerical columns. In this example, we'll create a scatter plot between columns 'A' and 'B'.

# %%
import matplotlib.pyplot as plt

# Create a scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(df_cleaned['age'], df_cleaned['avg_salary'], alpha=0.5, c='orange', edgecolors='k')
plt.title('Scatter Plot: Average Salary vs. Age')
plt.xlabel('Age')
plt.ylabel('Average Salary')
plt.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# Lower salary is concentrated with younger people

# %%
import matplotlib.pyplot as plt

# Create a scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(df_cleaned['Rating'], df_cleaned['avg_salary'], alpha=0.5, c='red', edgecolors='k')
plt.title('Scatter Plot: Average Salary vs. Rating')
plt.xlabel('Rating')
plt.ylabel('Average Salary in 1000s')
plt.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# Very hard to see the relationship

# %% [markdown]
# ## Interpretation

# %% [markdown]
# ## Histogram:
#
# Create a histogram to visualize the distribution of a single numerical column. In this example, we'll create a histogram for column 'C'.

# %% [markdown]
# Finding the counts of the max salaries

# %%
plt.figure(figsize=(8, 6))
plt.hist(df['max_salary'], bins=20, edgecolor='k')
plt.title('Histogram of Max salary')
plt.xlabel('Max Salary')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# HIgh frequency areas are between 100-150k

# %% [markdown]
# minimum salaries histogram

# %%
sns.histplot(data=df_cleaned, x="min_salary", kde=True)
# Out:
# <Axes: xlabel='min_salary', ylabel='Count'>

# %% [markdown]
# HIgh frequency spots are under 100k

# %% [markdown]
# ## Interpretation

# %% [markdown]
# # Correlation Heatmap:
#
# Create a correlation heatmap to visualize the pairwise correlation between numerical columns. This can help identify relationships between columns.

# %% [markdown]
# Finding the correlation for all the numerical variables?

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Select the columns of interest
columns_of_Heatmap = ['Rating', 'employer_provided', 'min_salary', 'max_salary', 'avg_salary', 'age']

# Create a DataFrame with only the selected columns
selected_data = df[columns_of_Heatmap]

# Compute the correlation matrix
correlation_matrix = selected_data.corr()

# Create a heatmap with the "Pastel1" colormap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='Pastel1', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# No high correlation between non salary attributes
